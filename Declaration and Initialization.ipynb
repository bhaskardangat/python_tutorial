# %% [markdown]
# # Declaration and Initialization

# %% [markdown]
# ### A variable has 2 properties :
# ###    1. Type of value it will have
# ###    2. The value itself

# %%
a = 10
a
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# ### In C, Java we have to first declare a varibale and then initialise it or else it will throw an error, like in the following image:
# ![Screenshot%202021-10-25%20at%207.03.03%20PM.png](attachment:Screenshot%202021-10-25%20at%207.03.03%20PM.png)

# %% [markdown]
# ### but in python there is no such restriction. We dont have to necessarilly declare the type of the variable. The Python interpreter understands the type of the value during run time and implicitly assigns the type. this property of assigning the datatype is called as Dynamic Typing
